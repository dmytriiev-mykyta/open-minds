# %%
import re


# s = 'Sakh.online'
# s = 'ak-bars.ru'
# s = 'freepik.com'
# s = 'ru.freepik.com'
# s = 'ojm.tatarstan.ru'
s = 'https://otkroyrot.com/join'
website_pattern = re.compile('(https?://)?[a-zA-Z\\d][\\w\\-]*(\\.[a-zA-Z\\d][\\w\\-]*[a-zA-Z\\d])*\\.[\\w\\-]*[a-zA-Z\\d]')

m = website_pattern.search(s)

if m is None:
    print('No matches found')
else:
    print(m)
# Out:
# <re.Match object; span=(0, 21), match='https://otkroyrot.com'>

# %%
s = '''Перед Ленинградской областью стоит федеральная задача ввести в оборот около 40 тысяч гектар пашни. В планах на текущий год - ввести не менее 3,2 тысячи гектар сельскохозяйственных угодий. На учет намерены поставить 4,2 тысячи гектар сельхозземель.
                                      Такими данными в понедельник, 19 февраля, делится пресс-служба региональной администрации. Отмечается, что ключевая роль в плане отводится муниципальному земельному контролю.  В 2023 году надзорные мероприятия муниципального земельного контроля носили профилактический характер из-за моратория на проверки. Как подчеркнул губернатор Александр Дрозденко, в связи с этим необходимо активно направлять в прокуратуру заявления о согласовании внеплановых проверок по индикаторам риска и сотрудничать с Северо-Западным межрегиональным управлением Федеральной службы по ветеринарному и фитосанитарному надзору.За прошлый год в регионе провели 915 проверок в отношении сельхозземель. Всего было выдано 745 предостережений - в 1,4 раза больше чем в 2022 году. 
                          
                          Фото: Анастасия Илюшина\47channel
Tags: сельское хозяйство, сельххозземли'''

p = re.compile('\\b(Видео|Фото): .+$', re.IGNORECASE)

lines = s.split('\n')
_lines = [re.sub(p, '', l.strip(' \t')) for l in lines]

_s = '\n'.join(_lines)

print(_s)
# Out:
# Перед Ленинградской областью стоит федеральная задача ввести в оборот около 40 тысяч гектар пашни. В планах на текущий год - ввести не менее 3,2 тысячи гектар сельскохозяйственных угодий. На учет намерены поставить 4,2 тысячи гектар сельхозземель.
# ...
